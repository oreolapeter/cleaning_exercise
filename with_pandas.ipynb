# %%
! pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/b7/f8/32d6b5aa4c4bc045fa2c4c58f88c325facc54721956c6313f0afea8ea853/pandas-2.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy>=1.23.2 from https://files.pythonhosted.org/packages/72/b2/02770e60c4e2f7e158d923ab0dea4e9f146a2dbf267fec6d8dc61d475689/numpy-1.25.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      - -------------------------------------- 10.2/341.8 kB ? eta -:--:--
#      --- --------------------------------- 30.7/341.8 kB 435.7 kB/s eta 0:00:01
#      ---- -------------------------------- 41.0/341.8 kB 245.8 kB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('columns.txt')

df
# Out:
#   task;status;trackerID;serverregion;timestamp;server
# 0                                        Description
# 1  task: The task performed by the executed function
# 2                       status: The execution status
# 3  trackerID: The executionID used to track these...
# 4  serverregion: The location of the server on wh...
# 5      timestamp: The time the function was executed
# 6  server: The IP address of the server on which ...

# %%
my_data = pd.read_csv('log.txt',header=None,sep='|')

# %%
df2 = pd.DataFrame(my_data)

df2

df2.head(5)
# Out:
#                                         0        1            2  \
# 0                  Data quality assurance  success  89328463487
# 1  Designing and implementing data models  success  89328463488
# 2    Extracting data from various sources  success  89328463489
# 3      Loading data into a data warehouse  success  89328463490
# 4                  Data quality assurance  success  89328463491
#
#                       3              4  \
# 0           Florida;USA  1599093305000
# 1        Ontario;Canada  1589218599000
# 2        California;USA  1595463446000
# 3           Florida;USA  1605932487000
# 4  Queensland;Australia  1587354266000
#
#                                          5
# 0    464f:bdbd:1d:535a:2dad:5117:a92f:b359
# 1  1366:c314:8d40:4219:4a51:138f:7ce3:d244
# 2  1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c
# 3  8ac5:9010:f24c:2f06:4679:aaec:a737:f003
# 4  5a7d:18ec:4650:5421:185c:4fa0:2e86:6643

# %%
column = ['Task','Status','trackerID','serverregion','timestamp','server']
df2.columns = [column]

# %%
df2
# Out:
#                                        Task   Status    trackerID  \
# 0                    Data quality assurance  success  89328463487
# 1    Designing and implementing data models  success  89328463488
# 2      Extracting data from various sources  success  89328463489
# 3        Loading data into a data warehouse  success  89328463490
# 4                    Data quality assurance  success  89328463491
# ..                                      ...      ...          ...
# 995                         Data governance  success  89328464482
# 996         Optimizing database performance   failed  89328464483
# 997         Optimizing database performance  success  89328464484
# 998                 Building data pipelines  success  89328464485
# 999  Designing and implementing data models  success  89328464486
#
#              serverregion      timestamp  \
# 0             Florida;USA  1599093305000
# 1          Ontario;Canada  1589218599000
# 2          California;USA  1595463446000
# ...
